# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_1 = pd.read_csv('gmm01f_1.out', skiprows=18, delim_whitespace=True, header=0)
data_9 = pd.read_csv('gmm01f.out', skiprows=18, delim_whitespace=True, header=0)
data_ex = pd.read_csv('exam_1.data', skiprows=16, delim_whitespace=True, header=0
#data.index = data.index +1
#years = str(year)
data_ex.shape
#data.colums = list(range(1880,2014))
#data.set_axis(years, axis=1)
# Out:
#   File "<ipython-input-73-0a1865f46db5>", line 6
#     data_ex.shape
#           ^
# SyntaxError: invalid syntax

# %%
data_ex
#data_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-7bc9402ba9c1> in <module>
# ----> 1 data_ex
#       2 #data_1
#
# NameError: name 'data_ex' is not defined

# %%
y_9=data_9['itotal']
x_9=data_9['s.a.']
#y_1=data_1['itotal']
#x_1=data_1['s.a.']
plt.figure(figsize=(6,6))
plt.rcParams.update({'font.size': 20})
plt.plot(x_9,np.log(y_9), '.')
plt.xlabel('Scatter angle')
plt.ylabel(r'$\log_{10}(i_{12})$')
plt.show()

# %%
y_9=data_9['pol.']
x_9=data_9['s.a.']
#y_1=data_1['pol.']
#x_1=data_1['s.a.']
plt.figure(figsize=(6,6))
plt.rcParams.update({'font.size': 20})
plt.plot(x_9,np.log(y_9), '.')
plt.xlabel('Scatter angle')
plt.ylabel('polarisation')
plt.show()
